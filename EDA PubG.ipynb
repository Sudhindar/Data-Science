# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
df_train = pd.read_csv("F:\\ipynb files\\ML Sessions\\pubg-finish-placement-prediction\\train_V2.csv")

# %%
df_train.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# ...

# %%
df_train.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
sns.distplot(df_train['killPoints'])

# %%
df_train['killPoints'].describe()
df_train['killPoints'].value_counts()
# Out:
# 0       2655647
# 1000     137679
# 1256       3433
# 1233       3334
# 1268       3320
#          ...
# 375           1
# 372           1
# 796           1
# 798           1
# 2170          1
# Name: killPoints, Length: 1707, dtype: int64

# %%
df_train.loc[(df_train['killPoints']== 0)]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 1        eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2        1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3        4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4        315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5        ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# ...                 ...             ...             ...      ...     ...
# 4446960  69fa4c2d5431b1  2a3ad0e37fb6ce  818ccf2160343f        0       0
# 4446962  f4197cf374e6c0  408cdb5c46b2ac  ee854b837376d9        0       1
# 4446963  e1948b1295c88a  e26ac84bdf7cef  6d0cd12784f1ab        0       0
# 4446964  cc032cdd73b7ac  c2223f35411394  c9c701d0ad758a        0       4
# 4446965  0d8e7ed728b6fd  8c74f72fedf5ff  62a16aabcc095c        0       2
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# ...

# %%
df_train.corr().nlargest(10, 'killPoints') ['killPoints'].index
# Out:
# Index(['killPoints', 'winPoints', 'damageDealt', 'DBNOs', 'assists',
#        'killStreaks', 'kills', 'headshotKills', 'longestKill', 'winPlacePerc'],
#       dtype='object')

# %%
plt.subplots(figsize=(8,6))
fig = sns.boxplot(x = "longestKill",y='killPoints',data = df_train)
fig.axis(ymin=0,ymax=1100)
