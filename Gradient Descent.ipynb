# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("F:\ipynb files\ML Sessions\data.csv")

# %%
data.head()
# Out:
#    32.502345269453031  31.70700584656992
# 0           53.426804          68.777596
# 1           61.530358          62.562382
# 2           47.475640          71.546632
# 3           59.813208          87.230925
# 4           55.142188          78.211518

# %%
X = data.iloc[:,0]
Y = data.iloc[:,1]
plt.scatter(X,Y)

# %%
plt.show()

# %%
#Predicting

m = 0
c = 0

Y_pred = m*X + c

# %%
plt.scatter(X,Y)

# %%
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color = 'red')
plt.show()

# %%
# Build Gradient Descent Model

# Initializing m, c, learning rate and iterations

m = 0 
c = 0 

L = 0.0001
iter_ = 1000

n = float(len(X))
print(n)
# Out:
# 99.0

# %%
# Performing the Gradient Descent

for i in range(iter_):
    Y_pred = m*X + c
    D_m = (-2/n)*sum(X*(Y-Y_pred))
    D_c = (-2/n)*sum(Y-Y_pred)
    m = m - (L*D_m)
    c = c - (L*D_c)
    print ("Slope & Intercept for iteration: ", i+1)
    print ("Slope: ",m)
    print ("Intercept: ",c)
    
print("After 1000 iterations values of slope: %2f and intercept: %2f"%(m,c))
Y_pred = m*X + c
plt.scatter(X,Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color = 'red')
plt.show()
# Out:
# Slope & Intercept for iteration:  1
# Slope:  0.7424335285415494
# Intercept:  0.014629895049539552
# Slope & Intercept for iteration:  2
# Slope:  1.1126970531564835
# Intercept:  0.02196251949501772
# Slope & Intercept for iteration:  3
# Slope:  1.2973530613136097
# Intercept:  0.02565587059950957
# Slope & Intercept for iteration:  4
# Slope:  1.3894434413943608
# Intercept:  0.027534253868739502
# Slope & Intercept for iteration:  5
# Slope:  1.4353697670003447
# Intercept:  0.028507481513835913
# Slope & Intercept for iteration:  6
# Slope:  1.4582732927875135
# Intercept:  0.02902929237235795
# Slope & Intercept for iteration:  7
# Slope:  1.4696949563897819
# Intercept:  0.029325973726661497
# Slope & Intercept for iteration:  8
# Slope:  1.4753904198682661
# Intercept:  0.02951037889658117
# Slope & Intercept for iteration:  9
# Slope:  1.478230129872329
# Intercept:  0.029638789753839184
# Slope & Intercept for iteration:  10
# Slope:  1.4796456270100444
# Intercept:  0.02973927502595998
# Slope & Intercept for iteration:  11
# Slope:  1.4803508449519853
# Intercept:  0.029825833065180055
# Slope & Intercept for iteration:  12
# Slope:  1.4807018345730651
# Intercept:  0.02990544508805775
# Slope & Intercept for iteration:  13
# Slope:  1.4808761645057094
# Intercept:  0.029981592746134954
# Slope & Intercept for iteration:  14
# Slope:  1.4809623912496854
# Intercept:  0.030056012398306246
# Slope & Intercept for iteration:  15
# Slope:  1.4810046794389382
# Intercept:  0.030129569996312628
# Slope & Intercept for iteration:  16
# Slope:  1.4810250547282364
# Intercept:  0.03020269740503053
# Slope & Intercept for iteration:  17
# Slope:  1.4810345016865596
# Intercept:  0.030275610002827507
# Slope & Intercept for iteration:  18
# Slope:  1.4810384985054497
# Intercept:  0.03034841520256384
# Slope & Intercept for iteration:  19
# Slope:  1.4810397772522843
# Intercept:  0.03042116657286344
# Slope & Intercept for iteration:  20
# Slope:  1.4810397004555735
# Intercept:  0.030493890829312927
# Slope & Intercept for iteration:  21
# Slope:  1.4810389476314794
# Intercept:  0.030566601295432105
# Slope & Intercept for iteration:  22
# Slope:  1.4810378576662797
# Intercept:  0.030639304615889085
# Slope & Intercept for iteration:  23
# Slope:  1.48103659956833
# Intercept:  0.030712004104494938
# Slope & Intercept for iteration:  24
# Slope:  1.4810352576249737
# Intercept:  0.03078470141390563
# Slope & Intercept for iteration:  25
# Slope:  1.4810338738717446
# Intercept:  0.0308573973683308
# Slope & Intercept for iteration:  26
# Slope:  1.4810324692724783
# Intercept:  0.030930092378819805
# Slope & Intercept for iteration:  27
# Slope:  1.481031054282197
# Intercept:  0.03100278665037192
# Slope & Intercept for iteration:  28
# Slope:  1.4810296341149976
# Intercept:  0.031075480285225752
# Slope & Intercept for iteration:  29
# Slope:  1.4810282113712394
# Intercept:  0.031148173334371407
# Slope & Intercept for iteration:  30
# Slope:  1.4810267873477656
# Intercept:  0.031220865823240494
# Slope & Intercept for iteration:  31
# Slope:  1.481025362691334
# Intercept:  0.03129355776451816
# Slope & Intercept for iteration:  32
# Slope:  1.4810239377244936
# Intercept:  0.03136624916453268
# Slope & Intercept for iteration:  33
# Slope:  1.4810225126081051
# Intercept:  0.03143894002644204
# Slope & Intercept for iteration:  34
# Slope:  1.4810210874223924
# Intercept:  0.031511630351823174
# Slope & Intercept for iteration:  35
# Slope:  1.4810196622073646
# Intercept:  0.03158432014146448
# Slope & Intercept for iteration:  36
# Slope:  1.481018236982975
# Intercept:  0.031657009395761125
# Slope & Intercept for iteration:  37
# Slope:  1.4810168117591742
# Intercept:  0.03172969811491216
# Slope & Intercept for iteration:  38
# Slope:  1.481015386540925
# Intercept:  0.03180238629901882
# Slope & Intercept for iteration:  39
# Slope:  1.4810139613307023
# Intercept:  0.031875073948133575
# Slope & Intercept for iteration:  40
# Slope:  1.4810125361297404
# Intercept:  0.03194776106228457
# Slope & Intercept for iteration:  41
# Slope:  1.4810111109386546
# Intercept:  0.03202044764148781
# Slope & Intercept for iteration:  42
# Slope:  1.481009685757752
# Intercept:  0.03209313368575325
# Slope & Intercept for iteration:  43
# Slope:  1.4810082605871857
# Intercept:  0.032165819195087826
# Slope & Intercept for iteration:  44
# Slope:  1.4810068354270318
# Intercept:  0.03223850416949697
# Slope & Intercept for iteration:  45
# Slope:  1.4810054102773285
# Intercept:  0.032311188608985374
# Slope & Intercept for iteration:  46
# Slope:  1.4810039851380943
# Intercept:  0.03238387251355734
# Slope & Intercept for iteration:  47
# Slope:  1.481002560009339
# Intercept:  0.03245655588321699
# Slope & Intercept for iteration:  48
# Slope:  1.4810011348910674
# Intercept:  0.03252923871796836
# Slope & Intercept for iteration:  49
# Slope:  1.4809997097832812
# Intercept:  0.03260192101781543
# Slope & Intercept for iteration:  50
# Slope:  1.480998284685982
# Intercept:  0.03267460278276216
# Slope & Intercept for iteration:  51
# Slope:  1.48099685959917
# Intercept:  0.03274728401281249
# Slope & Intercept for iteration:  52
# Slope:  1.4809954345228458
# Intercept:  0.03281996470797037
# Slope & Intercept for iteration:  53
# Slope:  1.4809940094570089
# Intercept:  0.032892644868239736
# Slope & Intercept for iteration:  54
# Slope:  1.4809925844016596
# Intercept:  0.03296532449362453
# Slope & Intercept for iteration:  55
# Slope:  1.480991159356798
# Intercept:  0.033038003584128686
# Slope & Intercept for iteration:  56
# Slope:  1.4809897343224239
# Intercept:  0.03311068213975615
# Slope & Intercept for iteration:  57
# Slope:  1.4809883092985372
# Intercept:  0.03318336016051084
# Slope & Intercept for iteration:  58
# Slope:  1.480986884285138
# Intercept:  0.03325603764639671
# Slope & Intercept for iteration:  59
# Slope:  1.4809854592822258
# Intercept:  0.03332871459741768
# Slope & Intercept for iteration:  60
# Slope:  1.480984034289801
# Intercept:  0.033401391013577704
# Slope & Intercept for iteration:  61
# Slope:  1.4809826093078633
# Intercept:  0.0334740668948807
# Slope & Intercept for iteration:  62
# Slope:  1.4809811843364127
# Intercept:  0.03354674224133062
# Slope & Intercept for iteration:  63
# Slope:  1.480979759375449
# Intercept:  0.033619417052931394
# Slope & Intercept for iteration:  64
# Slope:  1.4809783344249723
# Intercept:  0.03369209132968696
# Slope & Intercept for iteration:  65
# Slope:  1.4809769094849823
# Intercept:  0.03376476507160125
# Slope & Intercept for iteration:  66
# Slope:  1.4809754845554792
# Intercept:  0.0338374382786782
# Slope & Intercept for iteration:  67
# Slope:  1.4809740596364627
# Intercept:  0.03391011095092175
# Slope & Intercept for iteration:  68
# Slope:  1.4809726347279326
# Intercept:  0.033982783088335834
# Slope & Intercept for iteration:  69
# Slope:  1.4809712098298893
# Intercept:  0.03405545469092439
# Slope & Intercept for iteration:  70
# Slope:  1.4809697849423322
# Intercept:  0.034128125758691355
# Slope & Intercept for iteration:  71
# Slope:  1.4809683600652617
# Intercept:  0.03420079629164066
# Slope & Intercept for iteration:  72
# Slope:  1.4809669351986772
# Intercept:  0.03427346628977625
# Slope & Intercept for iteration:  73
# Slope:  1.480965510342579
# Intercept:  0.034346135753102046
# Slope & Intercept for iteration:  74
# Slope:  1.480964085496967
# Intercept:  0.034418804681622
# Slope & Intercept for iteration:  75
# Slope:  1.4809626606618411
# Intercept:  0.034491473075340034
# Slope & Intercept for iteration:  76
# Slope:  1.480961235837201
# Intercept:  0.03456414093426009
# Slope & Intercept for iteration:  77
# Slope:  1.4809598110230469
# Intercept:  0.03463680825838611
# Slope & Intercept for iteration:  78
# Slope:  1.4809583862193787
# Intercept:  0.034709475047722024
# Slope & Intercept for iteration:  79
# Slope:  1.4809569614261962
# Intercept:  0.034782141302271766
# Slope & Intercept for iteration:  80
# Slope:  1.4809555366434992
# Intercept:  0.034854807022039275
# Slope & Intercept for iteration:  81
# Slope:  1.480954111871288
# Intercept:  0.03492747220702848
# Slope & Intercept for iteration:  82
# Slope:  1.4809526871095622
# Intercept:  0.035000136857243326
# Slope & Intercept for iteration:  83
# Slope:  1.4809512623583219
# Intercept:  0.035072800972687744
# Slope & Intercept for iteration:  84
# Slope:  1.480949837617567
# Intercept:  0.03514546455336567
# Slope & Intercept for iteration:  85
# Slope:  1.4809484128872972
# Intercept:  0.035218127599281036
# Slope & Intercept for iteration:  86
# Slope:  1.4809469881675128
# Intercept:  0.035290790110437786
# Slope & Intercept for iteration:  87
# Slope:  1.4809455634582134
# Intercept:  0.035363452086839844
# Slope & Intercept for iteration:  88
# Slope:  1.4809441387593991
# Intercept:  0.03543611352849116
# Slope & Intercept for iteration:  89
# Slope:  1.4809427140710698
# Intercept:  0.03550877443539566
# Slope & Intercept for iteration:  90
# Slope:  1.4809412893932254
# Intercept:  0.03558143480755727
# Slope & Intercept for iteration:  91
# Slope:  1.4809398647258658
# Intercept:  0.03565409464497995
# Slope & Intercept for iteration:  92
# Slope:  1.480938440068991
# Intercept:  0.03572675394766761
# Slope & Intercept for iteration:  93
# Slope:  1.4809370154226007
# Intercept:  0.0357994127156242
# Slope & Intercept for iteration:  94
# Slope:  1.480935590786695
# Intercept:  0.035872070948853654
# Slope & Intercept for iteration:  95
# Slope:  1.4809341661612738
# Intercept:  0.035944728647359904
# Slope & Intercept for iteration:  96
# Slope:  1.4809327415463371
# Intercept:  0.03601738581114689
# Slope & Intercept for iteration:  97
# Slope:  1.4809313169418847
# Intercept:  0.036090042440218545
# Slope & Intercept for iteration:  98
# Slope:  1.4809298923479166
# Intercept:  0.036162698534578805
# Slope & Intercept for iteration:  99
# Slope:  1.4809284677644328
# Intercept:  0.0362353540942316
# Slope & Intercept for iteration:  100
# Slope:  1.4809270431914332
# Intercept:  0.03630800911918087
# Slope & Intercept for iteration:  101
# Slope:  1.4809256186289175
# Intercept:  0.03638066360943055
# Slope & Intercept for iteration:  102
# Slope:  1.4809241940768858
# Intercept:  0.03645331756498457
# Slope & Intercept for iteration:  103
# Slope:  1.480922769535338
# Intercept:  0.036525970985846874
# Slope & Intercept for iteration:  104
# Slope:  1.480921345004274
# Intercept:  0.03659862387202139
# Slope & Intercept for iteration:  105
# Slope:  1.4809199204836936
# Intercept:  0.03667127622351205
# Slope & Intercept for iteration:  106
# Slope:  1.480918495973597
# Intercept:  0.0367439280403228
# Slope & Intercept for iteration:  107
# Slope:  1.4809170714739839
# Intercept:  0.03681657932245757
# Slope & Intercept for iteration:  108
# Slope:  1.4809156469848543
# Intercept:  0.036889230069920294
# Slope & Intercept for iteration:  109
# Slope:  1.4809142225062084
# Intercept:  0.0369618802827149
# Slope & Intercept for iteration:  110
# Slope:  1.4809127980380457
# Intercept:  0.03703452996084533
# Slope & Intercept for iteration:  111
# Slope:  1.480911373580366
# Intercept:  0.03710717910431552
# Slope & Intercept for iteration:  112
# Slope:  1.4809099491331699
# Intercept:  0.0371798277131294
# Slope & Intercept for iteration:  113
# Slope:  1.4809085246964566
# Intercept:  0.03725247578729091
# Slope & Intercept for iteration:  114
# Slope:  1.4809071002702265
# Intercept:  0.03732512332680399
# Slope & Intercept for iteration:  115
# Slope:  1.4809056758544794
# Intercept:  0.03739777033167256
# Slope & Intercept for iteration:  116
# Slope:  1.4809042514492152
# Intercept:  0.037470416801900566
# Slope & Intercept for iteration:  117
# Slope:  1.4809028270544338
# Intercept:  0.03754306273749194
# Slope & Intercept for iteration:  118
# Slope:  1.4809014026701348
# Intercept:  0.03761570813845061
# Slope & Intercept for iteration:  119
# Slope:  1.4808999782963188
# Intercept:  0.03768835300478052
# Slope & Intercept for iteration:  120
# Slope:  1.4808985539329853
# Intercept:  0.037760997336485594
# Slope & Intercept for iteration:  121
# Slope:  1.4808971295801343
# Intercept:  0.037833641133569774
# Slope & Intercept for iteration:  122
# Slope:  1.4808957052377658
# Intercept:  0.037906284396037
# Slope & Intercept for iteration:  123
# Slope:  1.4808942809058796
# Intercept:  0.0379789271238912
# Slope & Intercept for iteration:  124
# Slope:  1.4808928565844757
# Intercept:  0.038051569317136304
# Slope & Intercept for iteration:  125
# Slope:  1.480891432273554
# Intercept:  0.03812421097577625
# Slope & Intercept for iteration:  126
# Slope:  1.4808900079731142
# Intercept:  0.03819685209981497
# Slope & Intercept for iteration:  127
# Slope:  1.4808885836831567
# Intercept:  0.03826949268925641
# Slope & Intercept for iteration:  128
# Slope:  1.480887159403681
# Intercept:  0.038342132744104494
# Slope & Intercept for iteration:  129
# Slope:  1.4808857351346874
# Intercept:  0.038414772264363156
# Slope & Intercept for iteration:  130
# Slope:  1.4808843108761753
# Intercept:  0.03848741125003633
# Slope & Intercept for iteration:  131
# Slope:  1.4808828866281452
# Intercept:  0.03856004970112796
# Slope & Intercept for iteration:  132
# Slope:  1.4808814623905966
# Intercept:  0.03863268761764197
# Slope & Intercept for iteration:  133
# Slope:  1.4808800381635296
# Intercept:  0.0387053249995823
# Slope & Intercept for iteration:  134
# Slope:  1.480878613946944
# Intercept:  0.038777961846952876
# Slope & Intercept for iteration:  135
# Slope:  1.4808771897408401
# Intercept:  0.03885059815975764
# Slope & Intercept for iteration:  136
# Slope:  1.4808757655452174
# Intercept:  0.03892323393800052
# Slope & Intercept for iteration:  137
# Slope:  1.480874341360076
# Intercept:  0.038995869181685454
# Slope & Intercept for iteration:  138
# Slope:  1.4808729171854158
# Intercept:  0.039068503890816376
# Slope & Intercept for iteration:  139
# Slope:  1.4808714930212366
# Intercept:  0.03914113806539722
# Slope & Intercept for iteration:  140
# Slope:  1.4808700688675385
# Intercept:  0.03921377170543192
# Slope & Intercept for iteration:  141
# Slope:  1.4808686447243213
# Intercept:  0.039286404810924415
# Slope & Intercept for iteration:  142
# Slope:  1.4808672205915852
# Intercept:  0.03935903738187863
# Slope & Intercept for iteration:  143
# Slope:  1.4808657964693297
# Intercept:  0.0394316694182985
# Slope & Intercept for iteration:  144
# Slope:  1.480864372357555
# Intercept:  0.03950430092018797
# Slope & Intercept for iteration:  145
# Slope:  1.480862948256261
# Intercept:  0.03957693188755095
# Slope & Intercept for iteration:  146
# Slope:  1.4808615241654475
# Intercept:  0.0396495623203914
# Slope & Intercept for iteration:  147
# Slope:  1.4808601000851145
# Intercept:  0.03972219221871324
# Slope & Intercept for iteration:  148
# Slope:  1.4808586760152618
# Intercept:  0.0397948215825204
# Slope & Intercept for iteration:  149
# Slope:  1.4808572519558896
# Intercept:  0.03986745041181683
# Slope & Intercept for iteration:  150
# Slope:  1.4808558279069977
# Intercept:  0.03994007870660645
# Slope & Intercept for iteration:  151
# Slope:  1.4808544038685858
# Intercept:  0.0400127064668932
# Slope & Intercept for iteration:  152
# Slope:  1.4808529798406542
# Intercept:  0.04008533369268101
# Slope & Intercept for iteration:  153
# Slope:  1.4808515558232025
# Intercept:  0.04015796038397381
# Slope & Intercept for iteration:  154
# Slope:  1.4808501318162308
# Intercept:  0.04023058654077554
# Slope & Intercept for iteration:  155
# Slope:  1.4808487078197392
# Intercept:  0.04030321216309014
# Slope & Intercept for iteration:  156
# Slope:  1.4808472838337272
# Intercept:  0.040375837250921524
# Slope & Intercept for iteration:  157
# Slope:  1.4808458598581948
# Intercept:  0.04044846180427364
# Slope & Intercept for iteration:  158
# Slope:  1.4808444358931423
# Intercept:  0.04052108582315042
# Slope & Intercept for iteration:  159
# Slope:  1.4808430119385694
# Intercept:  0.0405937093075558
# Slope & Intercept for iteration:  160
# Slope:  1.4808415879944758
# Intercept:  0.0406663322574937
# Slope & Intercept for iteration:  161
# Slope:  1.4808401640608617
# Intercept:  0.040738954672968064
# Slope & Intercept for iteration:  162
# Slope:  1.4808387401377268
# Intercept:  0.04081157655398283
# Slope & Intercept for iteration:  163
# Slope:  1.4808373162250712
# Intercept:  0.04088419790054192
# Slope & Intercept for iteration:  164
# Slope:  1.4808358923228948
# Intercept:  0.04095681871264928
# Slope & Intercept for iteration:  165
# Slope:  1.4808344684311976
# Intercept:  0.04102943899030883
# Slope & Intercept for iteration:  166
# Slope:  1.4808330445499793
# Intercept:  0.04110205873352451
# Slope & Intercept for iteration:  167
# Slope:  1.48083162067924
# Intercept:  0.04117467794230025
# Slope & Intercept for iteration:  168
# Slope:  1.4808301968189799
# Intercept:  0.04124729661663999
# Slope & Intercept for iteration:  169
# Slope:  1.4808287729691982
# Intercept:  0.04131991475654766
# Slope & Intercept for iteration:  170
# Slope:  1.4808273491298956
# Intercept:  0.04139253236202719
# Slope & Intercept for iteration:  171
# Slope:  1.4808259253010714
# Intercept:  0.041465149433082514
# Slope & Intercept for iteration:  172
# Slope:  1.4808245014827257
# Intercept:  0.04153776596971757
# Slope & Intercept for iteration:  173
# Slope:  1.4808230776748585
# Intercept:  0.041610381971936276
# Slope & Intercept for iteration:  174
# Slope:  1.48082165387747
# Intercept:  0.04168299743974258
# Slope & Intercept for iteration:  175
# Slope:  1.4808202300905595
# Intercept:  0.04175561237314041
# Slope & Intercept for iteration:  176
# Slope:  1.4808188063141274
# Intercept:  0.0418282267721337
# Slope & Intercept for iteration:  177
# Slope:  1.4808173825481734
# Intercept:  0.04190084063672638
# Slope & Intercept for iteration:  178
# Slope:  1.4808159587926975
# Intercept:  0.04197345396692239
# Slope & Intercept for iteration:  179
# Slope:  1.4808145350476996
# Intercept:  0.04204606676272566
# Slope & Intercept for iteration:  180
# Slope:  1.4808131113131797
# Intercept:  0.04211867902414012
# Slope & Intercept for iteration:  181
# Slope:  1.4808116875891377
# Intercept:  0.0421912907511697
# Slope & Intercept for iteration:  182
# Slope:  1.4808102638755736
# Intercept:  0.04226390194381834
# Slope & Intercept for iteration:  183
# Slope:  1.4808088401724873
# Intercept:  0.042336512602089975
# Slope & Intercept for iteration:  184
# Slope:  1.4808074164798783
# Intercept:  0.04240912272598853
# Slope & Intercept for iteration:  185
# Slope:  1.480805992797747
# Intercept:  0.04248173231551793
# Slope & Intercept for iteration:  186
# Slope:  1.4808045691260934
# Intercept:  0.042554341370682126
# Slope & Intercept for iteration:  187
# Slope:  1.4808031454649169
# Intercept:  0.04262694989148504
# Slope & Intercept for iteration:  188
# Slope:  1.480801721814218
# Intercept:  0.04269955787793061
# Slope & Intercept for iteration:  189
# Slope:  1.4808002981739963
# Intercept:  0.04277216533002277
# Slope & Intercept for iteration:  190
# Slope:  1.4807988745442517
# Intercept:  0.042844772247765436
# Slope & Intercept for iteration:  191
# Slope:  1.4807974509249842
# Intercept:  0.04291737863116256
# Slope & Intercept for iteration:  192
# Slope:  1.4807960273161938
# Intercept:  0.04298998448021806
# Slope & Intercept for iteration:  193
# Slope:  1.4807946037178803
# Intercept:  0.04306258979493588
# Slope & Intercept for iteration:  194
# Slope:  1.4807931801300436
# Intercept:  0.043135194575319946
# Slope & Intercept for iteration:  195
# Slope:  1.4807917565526838
# Intercept:  0.043207798821374196
# Slope & Intercept for iteration:  196
# Slope:  1.4807903329858008
# Intercept:  0.04328040253310256
# Slope & Intercept for iteration:  197
# Slope:  1.4807889094293942
# Intercept:  0.043353005710508964
# Slope & Intercept for iteration:  198
# Slope:  1.4807874858834642
# Intercept:  0.04342560835359734
# Slope & Intercept for iteration:  199
# Slope:  1.4807860623480107
# Intercept:  0.043498210462371636
# Slope & Intercept for iteration:  200
# Slope:  1.4807846388230337
# Intercept:  0.04357081203683577
# Slope & Intercept for iteration:  201
# Slope:  1.4807832153085332
# Intercept:  0.04364341307699368
# Slope & Intercept for iteration:  202
# Slope:  1.4807817918045088
# Intercept:  0.043716013582849295
# Slope & Intercept for iteration:  203
# Slope:  1.4807803683109604
# Intercept:  0.043788613554406546
# Slope & Intercept for iteration:  204
# Slope:  1.4807789448278883
# Intercept:  0.04386121299166937
# Slope & Intercept for iteration:  205
# Slope:  1.4807775213552923
# Intercept:  0.0439338118946417
# Slope & Intercept for iteration:  206
# Slope:  1.480776097893172
# Intercept:  0.04400641026332745
# Slope & Intercept for iteration:  207
# Slope:  1.4807746744415278
# Intercept:  0.04407900809773058
# Slope & Intercept for iteration:  208
# Slope:  1.4807732510003593
# Intercept:  0.04415160539785501
# Slope & Intercept for iteration:  209
# Slope:  1.4807718275696664
# Intercept:  0.044224202163704665
# Slope & Intercept for iteration:  210
# Slope:  1.4807704041494494
# Intercept:  0.044296798395283485
# Slope & Intercept for iteration:  211
# Slope:  1.4807689807397078
# Intercept:  0.044369394092595396
# Slope & Intercept for iteration:  212
# Slope:  1.4807675573404415
# Intercept:  0.04444198925564433
# Slope & Intercept for iteration:  213
# Slope:  1.480766133951651
# Intercept:  0.04451458388443423
# Slope & Intercept for iteration:  214
# Slope:  1.4807647105733355
# Intercept:  0.044587177978969016
# Slope & Intercept for iteration:  215
# Slope:  1.4807632872054954
# Intercept:  0.04465977153925263
# Slope & Intercept for iteration:  216
# Slope:  1.4807618638481306
# Intercept:  0.04473236456528899
# Slope & Intercept for iteration:  217
# Slope:  1.4807604405012407
# Intercept:  0.04480495705708204
# Slope & Intercept for iteration:  218
# Slope:  1.480759017164826
# Intercept:  0.044877549014635705
# Slope & Intercept for iteration:  219
# Slope:  1.4807575938388862
# Intercept:  0.04495014043795392
# Slope & Intercept for iteration:  220
# Slope:  1.4807561705234211
# Intercept:  0.04502273132704062
# Slope & Intercept for iteration:  221
# Slope:  1.4807547472184308
# Intercept:  0.045095321681899725
# Slope & Intercept for iteration:  222
# Slope:  1.4807533239239152
# Intercept:  0.04516791150253518
# Slope & Intercept for iteration:  223
# Slope:  1.4807519006398744
# Intercept:  0.04524050078895091
# Slope & Intercept for iteration:  224
# Slope:  1.480750477366308
# Intercept:  0.04531308954115084
# Slope & Intercept for iteration:  225
# Slope:  1.4807490541032162
# Intercept:  0.04538567775913891
# Slope & Intercept for iteration:  226
# Slope:  1.480747630850599
# Intercept:  0.04545826544291905
# Slope & Intercept for iteration:  227
# Slope:  1.4807462076084559
# Intercept:  0.045530852592495195
# Slope & Intercept for iteration:  228
# Slope:  1.4807447843767871
# Intercept:  0.04560343920787127
# Slope & Intercept for iteration:  229
# Slope:  1.4807433611555925
# Intercept:  0.04567602528905121
# Slope & Intercept for iteration:  230
# Slope:  1.4807419379448719
# Intercept:  0.04574861083603894
# Slope & Intercept for iteration:  231
# Slope:  1.4807405147446253
# Intercept:  0.045821195848838404
# Slope & Intercept for iteration:  232
# Slope:  1.4807390915548526
# Intercept:  0.045893780327453525
# Slope & Intercept for iteration:  233
# Slope:  1.480737668375554
# Intercept:  0.04596636427188824
# Slope & Intercept for iteration:  234
# Slope:  1.480736245206729
# Intercept:  0.04603894768214647
# Slope & Intercept for iteration:  235
# Slope:  1.4807348220483778
# Intercept:  0.04611153055823215
# Slope & Intercept for iteration:  236
# Slope:  1.4807333989005003
# Intercept:  0.04618411290014922
# Slope & Intercept for iteration:  237
# Slope:  1.4807319757630961
# Intercept:  0.0462566947079016
# Slope & Intercept for iteration:  238
# Slope:  1.4807305526361656
# Intercept:  0.04632927598149323
# Slope & Intercept for iteration:  239
# Slope:  1.4807291295197085
# Intercept:  0.04640185672092804
# Slope & Intercept for iteration:  240
# Slope:  1.4807277064137245
# Intercept:  0.04647443692620995
# Slope & Intercept for iteration:  241
# Slope:  1.480726283318214
# Intercept:  0.0465470165973429
# Slope & Intercept for iteration:  242
# Slope:  1.4807248602331766
# Intercept:  0.046619595734330825
# Slope & Intercept for iteration:  243
# Slope:  1.4807234371586124
# Intercept:  0.04669217433717765
# Slope & Intercept for iteration:  244
# Slope:  1.480722014094521
# Intercept:  0.0467647524058873
# Slope & Intercept for iteration:  245
# Slope:  1.4807205910409027
# Intercept:  0.04683732994046372
# Slope & Intercept for iteration:  246
# Slope:  1.4807191679977572
# Intercept:  0.04690990694091083
# Slope & Intercept for iteration:  247
# Slope:  1.4807177449650846
# Intercept:  0.046982483407232566
# Slope & Intercept for iteration:  248
# Slope:  1.4807163219428845
# Intercept:  0.04705505933943285
# Slope & Intercept for iteration:  249
# Slope:  1.4807148989311572
# Intercept:  0.047127634737515633
# Slope & Intercept for iteration:  250
# Slope:  1.4807134759299023
# Intercept:  0.04720020960148483
# Slope & Intercept for iteration:  251
# Slope:  1.48071205293912
# Intercept:  0.04727278393134437
# Slope & Intercept for iteration:  252
# Slope:  1.48071062995881
# Intercept:  0.04734535772709819
# Slope & Intercept for iteration:  253
# Slope:  1.4807092069889725
# Intercept:  0.047417930988750225
# Slope & Intercept for iteration:  254
# Slope:  1.4807077840296072
# Intercept:  0.047490503716304394
# Slope & Intercept for iteration:  255
# Slope:  1.480706361080714
# Intercept:  0.047563075909764635
# Slope & Intercept for iteration:  256
# Slope:  1.480704938142293
# Intercept:  0.047635647569134874
# Slope & Intercept for iteration:  257
# Slope:  1.480703515214344
# Intercept:  0.04770821869441905
# Slope & Intercept for iteration:  258
# Slope:  1.4807020922968668
# Intercept:  0.04778078928562108
# Slope & Intercept for iteration:  259
# Slope:  1.4807006693898614
# Intercept:  0.04785335934274491
# Slope & Intercept for iteration:  260
# Slope:  1.480699246493328
# Intercept:  0.047925928865794463
# Slope & Intercept for iteration:  261
# Slope:  1.480697823607266
# Intercept:  0.04799849785477367
# Slope & Intercept for iteration:  262
# Slope:  1.480696400731676
# Intercept:  0.04807106630968646
# Slope & Intercept for iteration:  263
# Slope:  1.4806949778665575
# Intercept:  0.04814363423053677
# Slope & Intercept for iteration:  264
# Slope:  1.4806935550119102
# Intercept:  0.04821620161732852
# Slope & Intercept for iteration:  265
# Slope:  1.4806921321677347
# Intercept:  0.04828876847006565
# Slope & Intercept for iteration:  266
# Slope:  1.4806907093340302
# Intercept:  0.04836133478875208
# Slope & Intercept for iteration:  267
# Slope:  1.480689286510797
# Intercept:  0.04843390057339175
# Slope & Intercept for iteration:  268
# Slope:  1.4806878636980352
# Intercept:  0.04850646582398859
# Slope & Intercept for iteration:  269
# Slope:  1.4806864408957443
# Intercept:  0.048579030540546526
# Slope & Intercept for iteration:  270
# Slope:  1.4806850181039244
# Intercept:  0.048651594723069486
# Slope & Intercept for iteration:  271
# Slope:  1.4806835953225754
# Intercept:  0.0487241583715614
# Slope & Intercept for iteration:  272
# Slope:  1.4806821725516974
# Intercept:  0.04879672148602621
# Slope & Intercept for iteration:  273
# Slope:  1.4806807497912902
# Intercept:  0.04886928406646783
# Slope & Intercept for iteration:  274
# Slope:  1.4806793270413534
# Intercept:  0.0489418461128902
# Slope & Intercept for iteration:  275
# Slope:  1.4806779043018874
# Intercept:  0.04901440762529725
# Slope & Intercept for iteration:  276
# Slope:  1.4806764815728921
# Intercept:  0.0490869686036929
# Slope & Intercept for iteration:  277
# Slope:  1.4806750588543671
# Intercept:  0.049159529048081095
# Slope & Intercept for iteration:  278
# Slope:  1.4806736361463126
# Intercept:  0.04923208895846576
# Slope & Intercept for iteration:  279
# Slope:  1.4806722134487285
# Intercept:  0.04930464833485082
# Slope & Intercept for iteration:  280
# Slope:  1.4806707907616143
# Intercept:  0.04937720717724021
# Slope & Intercept for iteration:  281
# Slope:  1.4806693680849705
# Intercept:  0.049449765485637856
# Slope & Intercept for iteration:  282
# Slope:  1.480667945418797
# Intercept:  0.04952232326004769
# Slope & Intercept for iteration:  283
# Slope:  1.4806665227630933
# Intercept:  0.04959488050047364
# Slope & Intercept for iteration:  284
# Slope:  1.4806651001178595
# Intercept:  0.049667437206919636
# Slope & Intercept for iteration:  285
# Slope:  1.4806636774830955
# Intercept:  0.04973999337938961
# Slope & Intercept for iteration:  286
# Slope:  1.4806622548588013
# Intercept:  0.049812549017887495
# Slope & Intercept for iteration:  287
# Slope:  1.480660832244977
# Intercept:  0.049885104122417215
# Slope & Intercept for iteration:  288
# Slope:  1.4806594096416221
# Intercept:  0.0499576586929827
# Slope & Intercept for iteration:  289
# Slope:  1.4806579870487369
# Intercept:  0.05003021272958788
# Slope & Intercept for iteration:  290
# Slope:  1.4806565644663212
# Intercept:  0.05010276623223669
# Slope & Intercept for iteration:  291
# Slope:  1.4806551418943747
# Intercept:  0.05017531920093305
# Slope & Intercept for iteration:  292
# Slope:  1.4806537193328977
# Intercept:  0.050247871635680896
# Slope & Intercept for iteration:  293
# Slope:  1.48065229678189
# Intercept:  0.05032042353648416
# Slope & Intercept for iteration:  294
# Slope:  1.4806508742413513
# Intercept:  0.05039297490334676
# Slope & Intercept for iteration:  295
# Slope:  1.4806494517112818
# Intercept:  0.05046552573627264
# Slope & Intercept for iteration:  296
# Slope:  1.4806480291916813
# Intercept:  0.050538076035265715
# Slope & Intercept for iteration:  297
# Slope:  1.4806466066825497
# Intercept:  0.05061062580032993
# Slope & Intercept for iteration:  298
# Slope:  1.4806451841838868
# Intercept:  0.0506831750314692
# Slope & Intercept for iteration:  299
# Slope:  1.480643761695693
# Intercept:  0.05075572372868747
# Slope & Intercept for iteration:  300
# Slope:  1.4806423392179675
# Intercept:  0.05082827189198865
# Slope & Intercept for iteration:  301
# Slope:  1.4806409167507109
# Intercept:  0.050900819521376685
# Slope & Intercept for iteration:  302
# Slope:  1.4806394942939227
# Intercept:  0.050973366616855496
# Slope & Intercept for iteration:  303
# Slope:  1.480638071847603
# Intercept:  0.05104591317842902
# Slope & Intercept for iteration:  304
# Slope:  1.480636649411752
# Intercept:  0.05111845920610118
# Slope & Intercept for iteration:  305
# Slope:  1.4806352269863692
# Intercept:  0.051191004699875906
# Slope & Intercept for iteration:  306
# Slope:  1.4806338045714544
# Intercept:  0.05126354965975712
# Slope & Intercept for iteration:  307
# Slope:  1.480632382167008
# Intercept:  0.05133609408574877
# Slope & Intercept for iteration:  308
# Slope:  1.4806309597730294
# Intercept:  0.05140863797785476
# Slope & Intercept for iteration:  309
# Slope:  1.4806295373895189
# Intercept:  0.05148118133607905
# Slope & Intercept for iteration:  310
# Slope:  1.4806281150164764
# Intercept:  0.05155372416042554
# Slope & Intercept for iteration:  311
# Slope:  1.4806266926539018
# Intercept:  0.051626266450898184
# Slope & Intercept for iteration:  312
# Slope:  1.480625270301795
# Intercept:  0.05169880820750089
# Slope & Intercept for iteration:  313
# Slope:  1.480623847960156
# Intercept:  0.0517713494302376
# Slope & Intercept for iteration:  314
# Slope:  1.4806224256289844
# Intercept:  0.05184389011911223
# Slope & Intercept for iteration:  315
# Slope:  1.4806210033082803
# Intercept:  0.05191643027412872
# Slope & Intercept for iteration:  316
# Slope:  1.4806195809980438
# Intercept:  0.051988969895291
# Slope & Intercept for iteration:  317
# Slope:  1.4806181586982747
# Intercept:  0.05206150898260299
# Slope & Intercept for iteration:  318
# Slope:  1.4806167364089728
# Intercept:  0.05213404753606863
# Slope & Intercept for iteration:  319
# Slope:  1.4806153141301384
# Intercept:  0.05220658555569184
# Slope & Intercept for iteration:  320
# Slope:  1.4806138918617708
# Intercept:  0.05227912304147655
# Slope & Intercept for iteration:  321
# Slope:  1.4806124696038705
# Intercept:  0.05235165999342669
# Slope & Intercept for iteration:  322
# Slope:  1.4806110473564373
# Intercept:  0.05242419641154619
# Slope & Intercept for iteration:  323
# Slope:  1.480609625119471
# Intercept:  0.052496732295838976
# Slope & Intercept for iteration:  324
# Slope:  1.4806082028929715
# Intercept:  0.05256926764630898
# Slope & Intercept for iteration:  325
# Slope:  1.4806067806769387
# Intercept:  0.05264180246296013
# Slope & Intercept for iteration:  326
# Slope:  1.4806053584713728
# Intercept:  0.05271433674579635
# Slope & Intercept for iteration:  327
# Slope:  1.4806039362762733
# Intercept:  0.05278687049482157
# Slope & Intercept for iteration:  328
# Slope:  1.4806025140916403
# Intercept:  0.05285940371003973
# Slope & Intercept for iteration:  329
# Slope:  1.480601091917474
# Intercept:  0.05293193639145474
# Slope & Intercept for iteration:  330
# Slope:  1.4805996697537738
# Intercept:  0.053004468539070544
# Slope & Intercept for iteration:  331
# Slope:  1.4805982476005402
# Intercept:  0.05307700015289106
# Slope & Intercept for iteration:  332
# Slope:  1.4805968254577726
# Intercept:  0.05314953123292022
# Slope & Intercept for iteration:  333
# Slope:  1.4805954033254713
# Intercept:  0.05322206177916195
# Slope & Intercept for iteration:  334
# Slope:  1.4805939812036362
# Intercept:  0.05329459179162019
# Slope & Intercept for iteration:  335
# Slope:  1.4805925590922668
# Intercept:  0.05336712127029885
# Slope & Intercept for iteration:  336
# Slope:  1.4805911369913636
# Intercept:  0.053439650215201875
# Slope & Intercept for iteration:  337
# Slope:  1.4805897149009262
# Intercept:  0.05351217862633319
# Slope & Intercept for iteration:  338
# Slope:  1.4805882928209546
# Intercept:  0.05358470650369671
# Slope & Intercept for iteration:  339
# Slope:  1.4805868707514487
# Intercept:  0.05365723384729638
# Slope & Intercept for iteration:  340
# Slope:  1.4805854486924084
# Intercept:  0.05372976065713611
# Slope & Intercept for iteration:  341
# Slope:  1.4805840266438335
# Intercept:  0.053802286933219846
# Slope & Intercept for iteration:  342
# Slope:  1.4805826046057242
# Intercept:  0.05387481267555151
# Slope & Intercept for iteration:  343
# Slope:  1.4805811825780804
# Intercept:  0.05394733788413503
# Slope & Intercept for iteration:  344
# Slope:  1.4805797605609017
# Intercept:  0.05401986255897433
# Slope & Intercept for iteration:  345
# Slope:  1.4805783385541882
# Intercept:  0.05409238670007334
# Slope & Intercept for iteration:  346
# Slope:  1.4805769165579399
# Intercept:  0.05416491030743599
# Slope & Intercept for iteration:  347
# Slope:  1.4805754945721568
# Intercept:  0.05423743338106621
# Slope & Intercept for iteration:  348
# Slope:  1.4805740725968386
# Intercept:  0.05430995592096792
# Slope & Intercept for iteration:  349
# Slope:  1.4805726506319854
# Intercept:  0.05438247792714506
# Slope & Intercept for iteration:  350
# Slope:  1.4805712286775972
# Intercept:  0.05445499939960155
# Slope & Intercept for iteration:  351
# Slope:  1.4805698067336737
# Intercept:  0.054527520338341316
# Slope & Intercept for iteration:  352
# Slope:  1.4805683848002147
# Intercept:  0.05460004074336829
# Slope & Intercept for iteration:  353
# Slope:  1.4805669628772204
# Intercept:  0.0546725606146864
# Slope & Intercept for iteration:  354
# Slope:  1.4805655409646907
# Intercept:  0.054745079952299575
# Slope & Intercept for iteration:  355
# Slope:  1.4805641190626255
# Intercept:  0.054817598756211734
# Slope & Intercept for iteration:  356
# Slope:  1.4805626971710246
# Intercept:  0.054890117026426814
# Slope & Intercept for iteration:  357
# Slope:  1.480561275289888
# Intercept:  0.054962634762948735
# Slope & Intercept for iteration:  358
# Slope:  1.4805598534192157
# Intercept:  0.05503515196578143
# Slope & Intercept for iteration:  359
# Slope:  1.4805584315590075
# Intercept:  0.05510766863492883
# Slope & Intercept for iteration:  360
# Slope:  1.4805570097092633
# Intercept:  0.05518018477039486
# Slope & Intercept for iteration:  361
# Slope:  1.4805555878699832
# Intercept:  0.055252700372183446
# Slope & Intercept for iteration:  362
# Slope:  1.4805541660411672
# Intercept:  0.05532521544029852
# Slope & Intercept for iteration:  363
# Slope:  1.4805527442228148
# Intercept:  0.055397729974743994
# Slope & Intercept for iteration:  364
# Slope:  1.4805513224149263
# Intercept:  0.05547024397552382
# Slope & Intercept for iteration:  365
# Slope:  1.4805499006175016
# Intercept:  0.0555427574426419
# Slope & Intercept for iteration:  366
# Slope:  1.4805484788305403
# Intercept:  0.05561527037610218
# Slope & Intercept for iteration:  367
# Slope:  1.4805470570540427
# Intercept:  0.05568778277590858
# Slope & Intercept for iteration:  368
# Slope:  1.4805456352880084
# Intercept:  0.05576029464206503
# Slope & Intercept for iteration:  369
# Slope:  1.4805442135324376
# Intercept:  0.055832805974575454
# Slope & Intercept for iteration:  370
# Slope:  1.4805427917873302
# Intercept:  0.055905316773443785
# Slope & Intercept for iteration:  371
# Slope:  1.480541370052686
# Intercept:  0.05597782703867394
# Slope & Intercept for iteration:  372
# Slope:  1.4805399483285047
# Intercept:  0.056050336770269854
# Slope & Intercept for iteration:  373
# Slope:  1.4805385266147866
# Intercept:  0.056122845968235455
# Slope & Intercept for iteration:  374
# Slope:  1.4805371049115317
# Intercept:  0.05619535463257467
# Slope & Intercept for iteration:  375
# Slope:  1.4805356832187395
# Intercept:  0.05626786276329142
# Slope & Intercept for iteration:  376
# Slope:  1.4805342615364103
# Intercept:  0.056340370360389636
# Slope & Intercept for iteration:  377
# Slope:  1.4805328398645439
# Intercept:  0.05641287742387325
# Slope & Intercept for iteration:  378
# Slope:  1.4805314182031402
# Intercept:  0.056485383953746186
# Slope & Intercept for iteration:  379
# Slope:  1.480529996552199
# Intercept:  0.05655788995001237
# Slope & Intercept for iteration:  380
# Slope:  1.4805285749117203
# Intercept:  0.05663039541267572
# Slope & Intercept for iteration:  381
# Slope:  1.480527153281704
# Intercept:  0.05670290034174018
# Slope & Intercept for iteration:  382
# Slope:  1.4805257316621503
# Intercept:  0.05677540473720967
# Slope & Intercept for iteration:  383
# Slope:  1.4805243100530587
# Intercept:  0.056847908599088115
# Slope & Intercept for iteration:  384
# Slope:  1.4805228884544295
# Intercept:  0.05692041192737944
# Slope & Intercept for iteration:  385
# Slope:  1.4805214668662625
# Intercept:  0.056992914722087576
# Slope & Intercept for iteration:  386
# Slope:  1.4805200452885574
# Intercept:  0.057065416983216447
# Slope & Intercept for iteration:  387
# Slope:  1.4805186237213144
# Intercept:  0.05713791871076998
# Slope & Intercept for iteration:  388
# Slope:  1.4805172021645334
# Intercept:  0.05721041990475211
# Slope & Intercept for iteration:  389
# Slope:  1.480515780618214
# Intercept:  0.057282920565166755
# Slope & Intercept for iteration:  390
# Slope:  1.4805143590823566
# Intercept:  0.05735542069201784
# Slope & Intercept for iteration:  391
# Slope:  1.4805129375569608
# Intercept:  0.057427920285309304
# Slope & Intercept for iteration:  392
# Slope:  1.4805115160420268
# Intercept:  0.05750041934504506
# Slope & Intercept for iteration:  393
# Slope:  1.4805100945375542
# Intercept:  0.05757291787122904
# Slope & Intercept for iteration:  394
# Slope:  1.480508673043543
# Intercept:  0.05764541586386517
# Slope & Intercept for iteration:  395
# Slope:  1.4805072515599933
# Intercept:  0.05771791332295738
# Slope & Intercept for iteration:  396
# Slope:  1.4805058300869047
# Intercept:  0.05779041024850959
# Slope & Intercept for iteration:  397
# Slope:  1.4805044086242776
# Intercept:  0.05786290664052573
# Slope & Intercept for iteration:  398
# Slope:  1.4805029871721116
# Intercept:  0.057935402499009726
# Slope & Intercept for iteration:  399
# Slope:  1.4805015657304066
# Intercept:  0.05800789782396551
# Slope & Intercept for iteration:  400
# Slope:  1.4805001442991625
# Intercept:  0.058080392615397
# Slope & Intercept for iteration:  401
# Slope:  1.4804987228783795
# Intercept:  0.05815288687330813
# Slope & Intercept for iteration:  402
# Slope:  1.4804973014680574
# Intercept:  0.05822538059770282
# Slope & Intercept for iteration:  403
# Slope:  1.4804958800681958
# Intercept:  0.058297873788584996
# Slope & Intercept for iteration:  404
# Slope:  1.480494458678795
# Intercept:  0.05837036644595859
# Slope & Intercept for iteration:  405
# Slope:  1.4804930372998548
# Intercept:  0.058442858569827526
# Slope & Intercept for iteration:  406
# Slope:  1.4804916159313752
# Intercept:  0.05851535016019573
# Slope & Intercept for iteration:  407
# Slope:  1.4804901945733562
# Intercept:  0.05858784121706713
# Slope & Intercept for iteration:  408
# Slope:  1.4804887732257974
# Intercept:  0.05866033174044565
# Slope & Intercept for iteration:  409
# Slope:  1.480487351888699
# Intercept:  0.05873282173033522
# Slope & Intercept for iteration:  410
# Slope:  1.4804859305620608
# Intercept:  0.05880531118673976
# Slope & Intercept for iteration:  411
# Slope:  1.4804845092458827
# Intercept:  0.058877800109663196
# Slope & Intercept for iteration:  412
# Slope:  1.4804830879401647
# Intercept:  0.05895028849910946
# Slope & Intercept for iteration:  413
# Slope:  1.4804816666449068
# Intercept:  0.059022776355082476
# Slope & Intercept for iteration:  414
# Slope:  1.4804802453601087
# Intercept:  0.05909526367758617
# Slope & Intercept for iteration:  415
# Slope:  1.4804788240857705
# Intercept:  0.059167750466624466
# Slope & Intercept for iteration:  416
# Slope:  1.480477402821892
# Intercept:  0.059240236722201293
# Slope & Intercept for iteration:  417
# Slope:  1.4804759815684734
# Intercept:  0.05931272244432057
# Slope & Intercept for iteration:  418
# Slope:  1.4804745603255143
# Intercept:  0.059385207632986235
# Slope & Intercept for iteration:  419
# Slope:  1.4804731390930146
# Intercept:  0.059457692288202205
# Slope & Intercept for iteration:  420
# Slope:  1.4804717178709745
# Intercept:  0.05953017640997241
# Slope & Intercept for iteration:  421
# Slope:  1.4804702966593937
# Intercept:  0.059602659998300764
# Slope & Intercept for iteration:  422
# Slope:  1.4804688754582722
# Intercept:  0.05967514305319121
# Slope & Intercept for iteration:  423
# Slope:  1.48046745426761
# Intercept:  0.05974762557464766
# Slope & Intercept for iteration:  424
# Slope:  1.480466033087407
# Intercept:  0.05982010756267406
# Slope & Intercept for iteration:  425
# Slope:  1.4804646119176632
# Intercept:  0.05989258901727431
# Slope & Intercept for iteration:  426
# Slope:  1.480463190758378
# Intercept:  0.059965069938452346
# Slope & Intercept for iteration:  427
# Slope:  1.4804617696095521
# Intercept:  0.0600375503262121
# Slope & Intercept for iteration:  428
# Slope:  1.480460348471185
# Intercept:  0.060110030180557494
# Slope & Intercept for iteration:  429
# Slope:  1.4804589273432764
# Intercept:  0.060182509501492454
# Slope & Intercept for iteration:  430
# Slope:  1.4804575062258267
# Intercept:  0.0602549882890209
# Slope & Intercept for iteration:  431
# Slope:  1.4804560851188355
# Intercept:  0.06032746654314676
# Slope & Intercept for iteration:  432
# Slope:  1.480454664022303
# Intercept:  0.06039994426387397
# Slope & Intercept for iteration:  433
# Slope:  1.480453242936229
# Intercept:  0.06047242145120644
# Slope & Intercept for iteration:  434
# Slope:  1.480451821860613
# Intercept:  0.0605448981051481
# Slope & Intercept for iteration:  435
# Slope:  1.4804504007954558
# Intercept:  0.06061737422570288
# Slope & Intercept for iteration:  436
# Slope:  1.4804489797407565
# Intercept:  0.06068984981287471
# Slope & Intercept for iteration:  437
# Slope:  1.4804475586965153
# Intercept:  0.0607623248666675
# Slope & Intercept for iteration:  438
# Slope:  1.4804461376627325
# Intercept:  0.060834799387085185
# Slope & Intercept for iteration:  439
# Slope:  1.4804447166394075
# Intercept:  0.06090727337413169
# Slope & Intercept for iteration:  440
# Slope:  1.4804432956265405
# Intercept:  0.06097974682781094
# Slope & Intercept for iteration:  441
# Slope:  1.4804418746241312
# Intercept:  0.06105221974812686
# Slope & Intercept for iteration:  442
# Slope:  1.4804404536321798
# Intercept:  0.061124692135083376
# Slope & Intercept for iteration:  443
# Slope:  1.480439032650686
# Intercept:  0.06119716398868441
# Slope & Intercept for iteration:  444
# Slope:  1.4804376116796498
# Intercept:  0.061269635308933895
# Slope & Intercept for iteration:  445
# Slope:  1.4804361907190713
# Intercept:  0.06134210609583575
# Slope & Intercept for iteration:  446
# Slope:  1.4804347697689502
# Intercept:  0.061414576349393894
# Slope & Intercept for iteration:  447
# Slope:  1.4804333488292865
# Intercept:  0.061487046069612264
# Slope & Intercept for iteration:  448
# Slope:  1.48043192790008
# Intercept:  0.06155951525649478
# Slope & Intercept for iteration:  449
# Slope:  1.4804305069813306
# Intercept:  0.06163198391004537
# Slope & Intercept for iteration:  450
# Slope:  1.4804290860730385
# Intercept:  0.06170445203026795
# Slope & Intercept for iteration:  451
# Slope:  1.4804276651752035
# Intercept:  0.06177691961716645
# Slope & Intercept for iteration:  452
# Slope:  1.4804262442878255
# Intercept:  0.0618493866707448
# Slope & Intercept for iteration:  453
# Slope:  1.4804248234109045
# Intercept:  0.06192185319100692
# Slope & Intercept for iteration:  454
# Slope:  1.4804234025444403
# Intercept:  0.06199431917795673
# Slope & Intercept for iteration:  455
# Slope:  1.4804219816884328
# Intercept:  0.06206678463159817
# Slope & Intercept for iteration:  456
# Slope:  1.480420560842882
# Intercept:  0.06213924955193515
# Slope & Intercept for iteration:  457
# Slope:  1.480419140007788
# Intercept:  0.062211713938971604
# Slope & Intercept for iteration:  458
# Slope:  1.4804177191831502
# Intercept:  0.06228417779271145
# Slope & Intercept for iteration:  459
# Slope:  1.480416298368969
# Intercept:  0.06235664111315862
# Slope & Intercept for iteration:  460
# Slope:  1.4804148775652444
# Intercept:  0.062429103900317036
# Slope & Intercept for iteration:  461
# Slope:  1.480413456771976
# Intercept:  0.06250156615419061
# Slope & Intercept for iteration:  462
# Slope:  1.4804120359891637
# Intercept:  0.06257402787478329
# Slope & Intercept for iteration:  463
# Slope:  1.4804106152168075
# Intercept:  0.06264648906209899
# Slope & Intercept for iteration:  464
# Slope:  1.4804091944549074
# Intercept:  0.06271894971614163
# Slope & Intercept for iteration:  465
# Slope:  1.4804077737034633
# Intercept:  0.06279140983691514
# Slope & Intercept for iteration:  466
# Slope:  1.4804063529624754
# Intercept:  0.06286386942442344
# Slope & Intercept for iteration:  467
# Slope:  1.480404932231943
# Intercept:  0.06293632847867046
# Slope & Intercept for iteration:  468
# Slope:  1.4804035115118666
# Intercept:  0.06300878699966013
# Slope & Intercept for iteration:  469
# Slope:  1.4804020908022457
# Intercept:  0.06308124498739635
# Slope & Intercept for iteration:  470
# Slope:  1.4804006701030805
# Intercept:  0.06315370244188306
# Slope & Intercept for iteration:  471
# Slope:  1.480399249414371
# Intercept:  0.0632261593631242
# Slope & Intercept for iteration:  472
# Slope:  1.4803978287361168
# Intercept:  0.06329861575112367
# Slope & Intercept for iteration:  473
# Slope:  1.480396408068318
# Intercept:  0.0633710716058854
# Slope & Intercept for iteration:  474
# Slope:  1.4803949874109745
# Intercept:  0.06344352692741331
# Slope & Intercept for iteration:  475
# Slope:  1.4803935667640862
# Intercept:  0.06351598171571135
# Slope & Intercept for iteration:  476
# Slope:  1.480392146127653
# Intercept:  0.06358843597078342
# Slope & Intercept for iteration:  477
# Slope:  1.480390725501675
# Intercept:  0.06366088969263345
# Slope & Intercept for iteration:  478
# Slope:  1.480389304886152
# Intercept:  0.06373334288126536
# Slope & Intercept for iteration:  479
# Slope:  1.480387884281084
# Intercept:  0.06380579553668309
# Slope & Intercept for iteration:  480
# Slope:  1.4803864636864708
# Intercept:  0.06387824765889054
# Slope & Intercept for iteration:  481
# Slope:  1.4803850431023122
# Intercept:  0.06395069924789165
# Slope & Intercept for iteration:  482
# Slope:  1.4803836225286082
# Intercept:  0.06402315030369035
# Slope & Intercept for iteration:  483
# Slope:  1.480382201965359
# Intercept:  0.06409560082629055
# Slope & Intercept for iteration:  484
# Slope:  1.4803807814125642
# Intercept:  0.06416805081569618
# Slope & Intercept for iteration:  485
# Slope:  1.480379360870224
# Intercept:  0.06424050027191117
# Slope & Intercept for iteration:  486
# Slope:  1.4803779403383384
# Intercept:  0.06431294919493943
# Slope & Intercept for iteration:  487
# Slope:  1.4803765198169068
# Intercept:  0.0643853975847849
# Slope & Intercept for iteration:  488
# Slope:  1.4803750993059295
# Intercept:  0.06445784544145149
# Slope & Intercept for iteration:  489
# Slope:  1.4803736788054063
# Intercept:  0.06453029276494313
# Slope & Intercept for iteration:  490
# Slope:  1.4803722583153371
# Intercept:  0.06460273955526374
# Slope & Intercept for iteration:  491
# Slope:  1.480370837835722
# Intercept:  0.06467518581241725
# Slope & Intercept for iteration:  492
# Slope:  1.480369417366561
# Intercept:  0.06474763153640758
# Slope & Intercept for iteration:  493
# Slope:  1.4803679969078536
# Intercept:  0.06482007672723866
# Slope & Intercept for iteration:  494
# Slope:  1.4803665764596001
# Intercept:  0.0648925213849144
# Slope & Intercept for iteration:  495
# Slope:  1.4803651560218003
# Intercept:  0.06496496550943874
# Slope & Intercept for iteration:  496
# Slope:  1.480363735594454
# Intercept:  0.0650374091008156
# ...
# Slope:  1.4798813957845771
# Intercept:  0.08963734952295144
# Slope & Intercept for iteration:  837
# Slope:  1.4798799789174306
# Intercept:  0.08970961153963809
# Slope & Intercept for iteration:  838
# Slope:  1.4798785620607116
# Intercept:  0.08978187302451747
# Slope & Intercept for iteration:  839
# Slope:  1.4798771452144195
# Intercept:  0.0898541339775935
# Slope & Intercept for iteration:  840
# Slope:  1.4798757283785549
# Intercept:  0.08992639439887007
# Slope & Intercept for iteration:  841
# Slope:  1.4798743115531172
# Intercept:  0.0899986542883511
# Slope & Intercept for iteration:  842
# Slope:  1.4798728947381066
# Intercept:  0.09007091364604053
# Slope & Intercept for iteration:  843
# Slope:  1.479871477933523
# Intercept:  0.09014317247194224
# Slope & Intercept for iteration:  844
# Slope:  1.4798700611393663
# Intercept:  0.09021543076606017
# Slope & Intercept for iteration:  845
# Slope:  1.4798686443556361
# Intercept:  0.09028768852839822
# Slope & Intercept for iteration:  846
# Slope:  1.479867227582333
# Intercept:  0.09035994575896031
# Slope & Intercept for iteration:  847
# Slope:  1.4798658108194565
# Intercept:  0.09043220245775034
# Slope & Intercept for iteration:  848
# Slope:  1.4798643940670064
# Intercept:  0.09050445862477223
# Slope & Intercept for iteration:  849
# Slope:  1.4798629773249827
# Intercept:  0.0905767142600299
# Slope & Intercept for iteration:  850
# Slope:  1.4798615605933856
# Intercept:  0.09064896936352726
# Slope & Intercept for iteration:  851
# Slope:  1.4798601438722148
# Intercept:  0.09072122393526823
# Slope & Intercept for iteration:  852
# Slope:  1.4798587271614703
# Intercept:  0.0907934779752567
# Slope & Intercept for iteration:  853
# Slope:  1.4798573104611519
# Intercept:  0.09086573148349661
# Slope & Intercept for iteration:  854
# Slope:  1.4798558937712598
# Intercept:  0.09093798445999186
# Slope & Intercept for iteration:  855
# Slope:  1.4798544770917934
# Intercept:  0.09101023690474637
# Slope & Intercept for iteration:  856
# Slope:  1.479853060422753
# Intercept:  0.09108248881776404
# Slope & Intercept for iteration:  857
# Slope:  1.479851643764139
# Intercept:  0.0911547401990488
# Slope & Intercept for iteration:  858
# Slope:  1.4798502271159504
# Intercept:  0.09122699104860456
# Slope & Intercept for iteration:  859
# Slope:  1.4798488104781875
# Intercept:  0.09129924136643522
# Slope & Intercept for iteration:  860
# Slope:  1.4798473938508503
# Intercept:  0.09137149115254471
# Slope & Intercept for iteration:  861
# Slope:  1.4798459772339387
# Intercept:  0.09144374040693694
# Slope & Intercept for iteration:  862
# Slope:  1.4798445606274526
# Intercept:  0.09151598912961581
# Slope & Intercept for iteration:  863
# Slope:  1.4798431440313917
# Intercept:  0.09158823732058524
# Slope & Intercept for iteration:  864
# Slope:  1.4798417274457565
# Intercept:  0.09166048497984915
# Slope & Intercept for iteration:  865
# Slope:  1.4798403108705462
# Intercept:  0.09173273210741144
# Slope & Intercept for iteration:  866
# Slope:  1.4798388943057612
# Intercept:  0.09180497870327603
# Slope & Intercept for iteration:  867
# Slope:  1.4798374777514014
# Intercept:  0.09187722476744685
# Slope & Intercept for iteration:  868
# Slope:  1.4798360612074666
# Intercept:  0.0919494702999278
# Slope & Intercept for iteration:  869
# Slope:  1.4798346446739568
# Intercept:  0.09202171530072278
# Slope & Intercept for iteration:  870
# Slope:  1.479833228150872
# Intercept:  0.09209395976983571
# Slope & Intercept for iteration:  871
# Slope:  1.4798318116382116
# Intercept:  0.09216620370727051
# Slope & Intercept for iteration:  872
# Slope:  1.4798303951359764
# Intercept:  0.09223844711303109
# Slope & Intercept for iteration:  873
# Slope:  1.4798289786441656
# Intercept:  0.09231068998712136
# Slope & Intercept for iteration:  874
# Slope:  1.4798275621627794
# Intercept:  0.09238293232954523
# Slope & Intercept for iteration:  875
# Slope:  1.4798261456918176
# Intercept:  0.09245517414030661
# Slope & Intercept for iteration:  876
# Slope:  1.4798247292312803
# Intercept:  0.09252741541940944
# Slope & Intercept for iteration:  877
# Slope:  1.4798233127811673
# Intercept:  0.0925996561668576
# Slope & Intercept for iteration:  878
# Slope:  1.4798218963414786
# Intercept:  0.09267189638265502
# Slope & Intercept for iteration:  879
# Slope:  1.479820479912214
# Intercept:  0.09274413606680561
# Slope & Intercept for iteration:  880
# Slope:  1.4798190634933737
# Intercept:  0.09281637521931327
# Slope & Intercept for iteration:  881
# Slope:  1.4798176470849573
# Intercept:  0.09288861384018193
# Slope & Intercept for iteration:  882
# Slope:  1.4798162306869649
# Intercept:  0.0929608519294155
# Slope & Intercept for iteration:  883
# Slope:  1.4798148142993963
# Intercept:  0.09303308948701788
# Slope & Intercept for iteration:  884
# Slope:  1.4798133979222516
# Intercept:  0.093105326512993
# Slope & Intercept for iteration:  885
# Slope:  1.4798119815555306
# Intercept:  0.09317756300734475
# Slope & Intercept for iteration:  886
# Slope:  1.4798105651992335
# Intercept:  0.09324979897007707
# Slope & Intercept for iteration:  887
# Slope:  1.4798091488533598
# Intercept:  0.09332203440119385
# Slope & Intercept for iteration:  888
# Slope:  1.4798077325179095
# Intercept:  0.09339426930069901
# Slope & Intercept for iteration:  889
# Slope:  1.4798063161928827
# Intercept:  0.09346650366859646
# Slope & Intercept for iteration:  890
# Slope:  1.4798048998782793
# Intercept:  0.09353873750489013
# Slope & Intercept for iteration:  891
# Slope:  1.4798034835740992
# Intercept:  0.0936109708095839
# Slope & Intercept for iteration:  892
# Slope:  1.479802067280342
# Intercept:  0.0936832035826817
# Slope & Intercept for iteration:  893
# Slope:  1.479800650997008
# Intercept:  0.09375543582418745
# Slope & Intercept for iteration:  894
# Slope:  1.4797992347240971
# Intercept:  0.09382766753410506
# Slope & Intercept for iteration:  895
# Slope:  1.4797978184616094
# Intercept:  0.09389989871243842
# Slope & Intercept for iteration:  896
# Slope:  1.4797964022095444
# Intercept:  0.09397212935919147
# Slope & Intercept for iteration:  897
# Slope:  1.4797949859679023
# Intercept:  0.09404435947436811
# Slope & Intercept for iteration:  898
# Slope:  1.4797935697366826
# Intercept:  0.09411658905797225
# Slope & Intercept for iteration:  899
# Slope:  1.4797921535158858
# Intercept:  0.0941888181100078
# Slope & Intercept for iteration:  900
# Slope:  1.4797907373055115
# Intercept:  0.09426104663047868
# Slope & Intercept for iteration:  901
# Slope:  1.4797893211055597
# Intercept:  0.0943332746193888
# Slope & Intercept for iteration:  902
# Slope:  1.4797879049160305
# Intercept:  0.09440550207674207
# Slope & Intercept for iteration:  903
# Slope:  1.4797864887369236
# Intercept:  0.09447772900254241
# Slope & Intercept for iteration:  904
# Slope:  1.4797850725682389
# Intercept:  0.09454995539679371
# Slope & Intercept for iteration:  905
# Slope:  1.4797836564099762
# Intercept:  0.09462218125949991
# Slope & Intercept for iteration:  906
# Slope:  1.479782240262136
# Intercept:  0.0946944065906649
# Slope & Intercept for iteration:  907
# Slope:  1.4797808241247177
# Intercept:  0.09476663139029261
# Slope & Intercept for iteration:  908
# Slope:  1.4797794079977213
# Intercept:  0.09483885565838693
# Slope & Intercept for iteration:  909
# Slope:  1.479777991881147
# Intercept:  0.09491107939495179
# Slope & Intercept for iteration:  910
# Slope:  1.479776575774994
# Intercept:  0.09498330259999109
# Slope & Intercept for iteration:  911
# Slope:  1.4797751596792632
# Intercept:  0.09505552527350876
# Slope & Intercept for iteration:  912
# Slope:  1.479773743593954
# Intercept:  0.0951277474155087
# Slope & Intercept for iteration:  913
# Slope:  1.4797723275190662
# Intercept:  0.09519996902599481
# Slope & Intercept for iteration:  914
# Slope:  1.4797709114545998
# Intercept:  0.09527219010497101
# Slope & Intercept for iteration:  915
# Slope:  1.4797694954005551
# Intercept:  0.09534441065244122
# Slope & Intercept for iteration:  916
# Slope:  1.4797680793569317
# Intercept:  0.09541663066840934
# Slope & Intercept for iteration:  917
# Slope:  1.4797666633237296
# Intercept:  0.09548885015287929
# Slope & Intercept for iteration:  918
# Slope:  1.4797652473009486
# Intercept:  0.09556106910585498
# Slope & Intercept for iteration:  919
# Slope:  1.4797638312885888
# Intercept:  0.09563328752734032
# Slope & Intercept for iteration:  920
# Slope:  1.47976241528665
# Intercept:  0.09570550541733923
# Slope & Intercept for iteration:  921
# Slope:  1.4797609992951322
# Intercept:  0.0957777227758556
# Slope & Intercept for iteration:  922
# Slope:  1.4797595833140353
# Intercept:  0.09584993960289336
# Slope & Intercept for iteration:  923
# Slope:  1.479758167343359
# Intercept:  0.0959221558984564
# Slope & Intercept for iteration:  924
# Slope:  1.4797567513831038
# Intercept:  0.09599437166254866
# Slope & Intercept for iteration:  925
# Slope:  1.479755335433269
# Intercept:  0.09606658689517404
# Slope & Intercept for iteration:  926
# Slope:  1.479753919493855
# Intercept:  0.09613880159633645
# Slope & Intercept for iteration:  927
# Slope:  1.4797525035648613
# Intercept:  0.0962110157660398
# Slope & Intercept for iteration:  928
# Slope:  1.479751087646288
# Intercept:  0.096283229404288
# Slope & Intercept for iteration:  929
# Slope:  1.479749671738135
# Intercept:  0.09635544251108497
# Slope & Intercept for iteration:  930
# Slope:  1.4797482558404027
# Intercept:  0.09642765508643461
# Slope & Intercept for iteration:  931
# Slope:  1.4797468399530904
# Intercept:  0.09649986713034084
# Slope & Intercept for iteration:  932
# Slope:  1.479745424076198
# Intercept:  0.09657207864280756
# Slope & Intercept for iteration:  933
# Slope:  1.479744008209726
# Intercept:  0.0966442896238387
# Slope & Intercept for iteration:  934
# Slope:  1.4797425923536738
# Intercept:  0.09671650007343814
# Slope & Intercept for iteration:  935
# Slope:  1.4797411765080413
# Intercept:  0.09678870999160982
# Slope & Intercept for iteration:  936
# Slope:  1.4797397606728289
# Intercept:  0.09686091937835764
# Slope & Intercept for iteration:  937
# Slope:  1.4797383448480361
# Intercept:  0.09693312823368551
# Slope & Intercept for iteration:  938
# Slope:  1.479736929033663
# Intercept:  0.09700533655759734
# Slope & Intercept for iteration:  939
# Slope:  1.4797355132297094
# Intercept:  0.09707754435009705
# Slope & Intercept for iteration:  940
# Slope:  1.4797340974361755
# Intercept:  0.09714975161118855
# Slope & Intercept for iteration:  941
# Slope:  1.479732681653061
# Intercept:  0.09722195834087574
# Slope & Intercept for iteration:  942
# Slope:  1.4797312658803656
# Intercept:  0.09729416453916254
# Slope & Intercept for iteration:  943
# Slope:  1.4797298501180898
# Intercept:  0.09736637020605285
# Slope & Intercept for iteration:  944
# Slope:  1.4797284343662331
# Intercept:  0.09743857534155059
# Slope & Intercept for iteration:  945
# Slope:  1.4797270186247955
# Intercept:  0.09751077994565967
# Slope & Intercept for iteration:  946
# Slope:  1.4797256028937769
# Intercept:  0.097582984018384
# Slope & Intercept for iteration:  947
# Slope:  1.4797241871731772
# Intercept:  0.09765518755972749
# Slope & Intercept for iteration:  948
# Slope:  1.4797227714629966
# Intercept:  0.09772739056969405
# Slope & Intercept for iteration:  949
# Slope:  1.4797213557632347
# Intercept:  0.0977995930482876
# Slope & Intercept for iteration:  950
# Slope:  1.4797199400738916
# Intercept:  0.09787179499551203
# Slope & Intercept for iteration:  951
# Slope:  1.479718524394967
# Intercept:  0.09794399641137128
# Slope & Intercept for iteration:  952
# Slope:  1.4797171087264611
# Intercept:  0.09801619729586923
# Slope & Intercept for iteration:  953
# Slope:  1.479715693068374
# Intercept:  0.09808839764900981
# Slope & Intercept for iteration:  954
# Slope:  1.479714277420705
# Intercept:  0.09816059747079692
# Slope & Intercept for iteration:  955
# Slope:  1.4797128617834545
# Intercept:  0.09823279676123448
# Slope & Intercept for iteration:  956
# Slope:  1.479711446156622
# Intercept:  0.09830499552032639
# Slope & Intercept for iteration:  957
# Slope:  1.479710030540208
# Intercept:  0.09837719374807656
# Slope & Intercept for iteration:  958
# Slope:  1.479708614934212
# Intercept:  0.09844939144448892
# Slope & Intercept for iteration:  959
# Slope:  1.4797071993386341
# Intercept:  0.09852158860956735
# Slope & Intercept for iteration:  960
# Slope:  1.4797057837534744
# Intercept:  0.09859378524331579
# Slope & Intercept for iteration:  961
# Slope:  1.4797043681787325
# Intercept:  0.09866598134573813
# Slope & Intercept for iteration:  962
# Slope:  1.4797029526144083
# Intercept:  0.0987381769168383
# Slope & Intercept for iteration:  963
# Slope:  1.4797015370605018
# Intercept:  0.09881037195662018
# Slope & Intercept for iteration:  964
# Slope:  1.4797001215170131
# Intercept:  0.09888256646508771
# Slope & Intercept for iteration:  965
# Slope:  1.479698705983942
# Intercept:  0.09895476044224479
# Slope & Intercept for iteration:  966
# Slope:  1.4796972904612884
# Intercept:  0.09902695388809532
# Slope & Intercept for iteration:  967
# Slope:  1.479695874949052
# Intercept:  0.09909914680264321
# Slope & Intercept for iteration:  968
# Slope:  1.4796944594472332
# Intercept:  0.0991713391858924
# Slope & Intercept for iteration:  969
# Slope:  1.4796930439558318
# Intercept:  0.09924353103784676
# Slope & Intercept for iteration:  970
# Slope:  1.4796916284748474
# Intercept:  0.09931572235851023
# Slope & Intercept for iteration:  971
# Slope:  1.4796902130042802
# Intercept:  0.0993879131478867
# Slope & Intercept for iteration:  972
# Slope:  1.47968879754413
# Intercept:  0.09946010340598008
# Slope & Intercept for iteration:  973
# Slope:  1.4796873820943968
# Intercept:  0.0995322931327943
# Slope & Intercept for iteration:  974
# Slope:  1.4796859666550806
# Intercept:  0.09960448232833324
# Slope & Intercept for iteration:  975
# Slope:  1.4796845512261811
# Intercept:  0.09967667099260084
# Slope & Intercept for iteration:  976
# Slope:  1.4796831358076983
# Intercept:  0.099748859125601
# Slope & Intercept for iteration:  977
# Slope:  1.4796817203996324
# Intercept:  0.09982104672733763
# Slope & Intercept for iteration:  978
# Slope:  1.4796803050019829
# Intercept:  0.09989323379781463
# Slope & Intercept for iteration:  979
# Slope:  1.47967888961475
# Intercept:  0.09996542033703593
# Slope & Intercept for iteration:  980
# Slope:  1.4796774742379335
# Intercept:  0.10003760634500541
# Slope & Intercept for iteration:  981
# Slope:  1.4796760588715334
# Intercept:  0.10010979182172701
# Slope & Intercept for iteration:  982
# Slope:  1.4796746435155497
# Intercept:  0.10018197676720463
# Slope & Intercept for iteration:  983
# Slope:  1.479673228169982
# Intercept:  0.10025416118144216
# Slope & Intercept for iteration:  984
# Slope:  1.4796718128348305
# Intercept:  0.10032634506444353
# Slope & Intercept for iteration:  985
# Slope:  1.479670397510095
# Intercept:  0.10039852841621265
# Slope & Intercept for iteration:  986
# Slope:  1.4796689821957758
# Intercept:  0.10047071123675343
# Slope & Intercept for iteration:  987
# Slope:  1.4796675668918724
# Intercept:  0.10054289352606977
# Slope & Intercept for iteration:  988
# Slope:  1.4796661515983847
# Intercept:  0.10061507528416558
# Slope & Intercept for iteration:  989
# Slope:  1.4796647363153128
# Intercept:  0.10068725651104476
# Slope & Intercept for iteration:  990
# Slope:  1.4796633210426564
# Intercept:  0.10075943720671125
# Slope & Intercept for iteration:  991
# Slope:  1.479661905780416
# Intercept:  0.10083161737116894
# Slope & Intercept for iteration:  992
# Slope:  1.4796604905285908
# Intercept:  0.10090379700442174
# Slope & Intercept for iteration:  993
# Slope:  1.4796590752871812
# Intercept:  0.10097597610647356
# Slope & Intercept for iteration:  994
# Slope:  1.4796576600561868
# Intercept:  0.1010481546773283
# Slope & Intercept for iteration:  995
# Slope:  1.4796562448356079
# Intercept:  0.10112033271698989
# Slope & Intercept for iteration:  996
# Slope:  1.4796548296254441
# Intercept:  0.10119251022546223
# Slope & Intercept for iteration:  997
# Slope:  1.4796534144256954
# Intercept:  0.10126468720274923
# Slope & Intercept for iteration:  998
# Slope:  1.479651999236362
# Intercept:  0.10133686364885479
# Slope & Intercept for iteration:  999
# Slope:  1.4796505840574432
# Intercept:  0.10140903956378283
# Slope & Intercept for iteration:  1000
# Slope:  1.4796491688889395
# Intercept:  0.10148121494753726
# After 1000 iterations values of slope: 1.479649 and intercept: 0.101481
